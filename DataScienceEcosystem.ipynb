# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <font color="blue"> Exercise 1: Create a Jupyter Notebook, Create a new Jupyter notebook called `DataScienceEcosystem.ipynb`</font>

# %% [markdown]
# Ans:
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# <font color="blue"> Exercise 2: Create markdown cell with title of the notebook, Create a markdown cell with the title Data Science Tools and Ecosystem using H1 style heading. </font>

# %% [markdown]
# Ans:
# # Data Science Tools and Ecosystem

# %% [markdown]
# <font color="blue"> Exercise 3 - Create a markdown cell for an introduction. Write an introductory sentence about the notebook such as the follows:In this notebook, Data Science Tools and Ecosystem are summarized. </font>

# %% [markdown]
# Ans: In this notebook, Data Science Tools and Ecosystem are summarized. These includes:
#   - Data Management
#   - Data Integration and Transformation
#   - Data Visualization
#   - Model Building
#   - Model Deployment
#   - Model Monitoring and Assessment
#   - and various other supporting tools

# %% [markdown]
# <font color="blue">Exercise 4 - Create a markdown cell to list data science languages
# Start the cell with an overview line such as: Some of the popular languages that Data Scientists use are:
# Then create an ordered list (i.e. numbered) listing 3 (or more) commonly used languages for data science.</font>

# %% [markdown]
# Ans: There are diverse programming languages options in data Science, choosing a programming language is based on on personal requirements, the specific problems to solve, and the intended audience. Some of the most popular options are listed below:
#  1. Python
#  2. R
#  3. SQL
#  4. Scala
#  5. Java
#  6. Julia
#  7. JavaScript
#  8. PHP
#  9. Go
# etc

# %% [markdown]
# <font color="blue"> Exercise 5 - Create a markdown cell to list data science libraries
# Add an overview line to the cell like:Some of the commonly used libraries used by Data Scientists include:
# Below this line add an ordered list listing 3 (or more) commonly used libraries in data science. </font>

# %% [markdown]
# Ans: Some of the commonly used libraries used by Data Scientists include:
#    1. Pandas
#    2. Scikit-learn (Machine learning)
#    3. Tensorflow, keras or Pytorch (Deep Learning)
#    4. Numpy
#    5. Scipy
#       etc

# %% [markdown]
# <font color="blue">Exercise 6 - Create a markdown cell with a table of Data Science tools Create a single column table in this cell with the first row containing the header Data Science Tools. The subsequent three rows in the table should indicate three development environment open source tools used in data science. </font>

# %% [markdown]
# Ans:
# |Data Science Tools|
# |---|
# | JupyterLab|
# | Rstudio |
# |Spyder |

# %% [markdown]
# <font color="blue">Exercise 7 - Create a markdown cell introducing arithmetic expression examples. Add a line in this cell with H3 style heading with text like:Below are a few examples of evaluating arithmetic expressions in Python. </font>

# %% [markdown]
# Ans
# ### Below are a few examples of evaluating arithmetic expressions in Python.
# Python supports these operations with the following operators: `+`, `-`, `*`, `/`, and more. Here are some examples:
#
# - **Addition**: `a = 5; b = 3; result = a + b`
# - **Subtraction**: `a = 10; b = 4; result = a - b`
# - **Multiplication**: `a = 7; b = 2; result = a * b`
# - **Division**: `a = 15; b = 3; result = a / b`

# %% [markdown]
# <font color="blue"> Exercise 8 - Create a code cell to multiply and add numbers In this code cell evaluate the expression (3*4)+5.
# Insert a comment line before the expression to explain the operation e.g.  This a simple arithmetic expression to mutiply then add integers.
# Then execute the cell to ensure the expression returns the expected output of 17 </font>

# %%
(3*4)+5  # This a simple arithmetic expression to mutiply then add integers
# Out:
# 17

# %% [markdown]
# <font color="blue"> Exercise 9 - Create a code cell to convert minutes to hours
# In this code cell write an expression that converts 200 minutes into hours.
# Insert a comment line before the expression to explain the operation e.g.  This will convert 200 minutes to hours by diving by 60.
# Run the cell to evaluate the expression. </font>

# %%
def min_to_hours(value = 200):
    """
    This will convert 200 minutes to hours by diving by 60
    Arguments: value -- integer
    Returns:
    hours: --integer
    """
    hours = value//60
    #minute = value%60  # uncomment to see remaing minutes
    return hours
print(min_to_hours())
# Out:
# 3

# %% [markdown]
# <font color="blue"> Exercise 10 - Insert a markdown cell to list Objectives Below the introduction cell created in Exercise 3, insert a new markdown cell to list the objectives that this notebook covered (i.e. some of the key takeaways from the course). In this new cell start with an introductory line titled: Objectives: in bold font. Then using an unordered list (bullets) indicate 3 to 5 items covered in this notebook, such as List popular languages for Data Science. </font>

# %% [markdown]
# Some of the objectives of this course are:
# - **Objectives**
#   - List popular languages for Data Science
#   - Data Science Tools
#   - Understanding working of the Github
#   - List of libraries required in Data Science

# %% [markdown]
# <font color="blue"> Exercise 11 - Create a markdown cell to indicate the Author's name
# In this markdown cell markdown cell include the following text Author in H2 style heading. Include your name as regular text below the word Author </font>

# %% [markdown]
# ## Author

# %% [markdown]
# Shambhu Bhandari Sharma

# %% [markdown]
# <font color="red">  Share your notebook through GitHub Upload your notebook to a public respository on GitHub. </font>

# %% [markdown]
# Ans: Done

# %% [markdown]
# <font color="red">  Take a screenshot of the first page of the notebook and save it as 1-notebook.png </font>
